# %% [markdown]
# <a href="https://colab.research.google.com/github/e19166/e19-4yp-Dynamic-Multi-Dimensional-Resource-Orchestration-in-Kubernetes/blob/main/hashgen_memory_reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('hashgen_memory_limit_reduction.csv')
df.head()  # to preview the data
# Out:
#                     Timestamp              Service  CPU Request  \
# 0  2025-05-11T05:31:20.445000  hash-gen-deployment          0.1
# 1  2025-05-11T05:31:50.505000  hash-gen-deployment          0.1
# 2  2025-05-11T05:32:20.577000  hash-gen-deployment          0.1
# 3  2025-05-11T05:32:50.646000  hash-gen-deployment          0.1
# 4  2025-05-11T05:33:20.721000  hash-gen-deployment          0.1
#
#    Memory Request  CPU Limit  Memory Limit   Latency  CPU Usage  Memory Usage
# 0       134217728        0.2     242221056  0.000537   0.003312     170971136
# 1       134217728        0.2     242221056  0.000537   0.007851     170971136
# 2       134217728        0.2     242221056  0.000537   0.009378     170971136
# 3       134217728        0.2     242221056  0.000705   0.008030     170971136
# 4       134217728        0.2     242221056  0.000753   0.008939     170971136

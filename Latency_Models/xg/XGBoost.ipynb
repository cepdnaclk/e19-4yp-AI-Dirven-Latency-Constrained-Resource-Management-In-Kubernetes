# %% [markdown]
# <a href="https://colab.research.google.com/github/cepdnaclk/e19-4yp-AI-Dirven-Latency-Constrained-Resource-Management-In-Kubernetes/blob/main/Latency_Models/xg/XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Service 1

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 7.5 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 16.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.2 colorlog-6.9.0 optuna-4.4.0

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import optuna

# Load and preprocess data
df = pd.read_csv("/content/service-1-deployment_dataset.csv")
df["Timestamp"] = pd.to_datetime(df["Timestamp"], format = 'mixed')
df = df.sort_values("Timestamp")

# Feature engineering
df["cpu_allocated"] = df["CPU Request"]
df["memory_allocated"] = df["Memory Request"]
df["cpu_usage_pct"] = df["CPU Usage"] / df["CPU Limit"]
df["memory_usage_pct"] = df["Memory Usage"] / df["Memory Limit"]
df["request_rate_rps"] = df["Request Rate"]
df["latency_p95_t"] = df["Latency"].shift(1)
df["burstiness_score"] = df["Request Rate"].rolling(5).max() - df["Request Rate"].rolling(5).mean()

# Drop rows with NaNs from shifting
df = df.dropna()

# Define features and target
features = [
    "cpu_allocated", "memory_allocated",
    "cpu_usage_pct", "memory_usage_pct",
    "request_rate_rps", "latency_p95_t",
    "burstiness_score"
]
X = df[features]
y = df["Latency"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Optuna objective function
def objective(trial):
    params = {
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
        "n_estimators": trial.suggest_int("n_estimators", 50, 300),
        "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
        "objective": "reg:squarederror",
        "verbosity": 0,
    }

    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)

    model = xgb.train(
        params=params,
        dtrain=dtrain,
        num_boost_round=params["n_estimators"]
    )

    preds = model.predict(dtest)
    mae = mean_absolute_error(y_test, preds)
    return mae

# Run Optuna tuning
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# Best model
best_params = study.best_params
best_params["objective"] = "reg:squarederror"
best_params["verbosity"] = 0

# Train base model on initial batch
batch_size = 100
model = None
for i in range(0, len(X_train), batch_size):
    X_batch = X_train.iloc[i:i + batch_size]
    y_batch = y_train.iloc[i:i + batch_size]
    dtrain = xgb.DMatrix(X_batch, label=y_batch)

    model = xgb.train(
        params=best_params,
        dtrain=dtrain,
        num_boost_round=best_params["n_estimators"] // 5,
        xgb_model=model,  # warm-start
        #process_type="update",
        #updater="refresh"
    )

# Evaluate on test set
dtest = xgb.DMatrix(X_test)
y_pred = model.predict(dtest)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Final MAE:", round(mae, 4))
print("Final R² Score:", round(r2, 4))
print("Best Parameters:", best_params)
# Out:
# [I 2025-06-30 05:28:26,463] A new study created in memory with name: no-name-3ac17339-ad84-4edd-b468-6fa94ff201a1
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:26,532] Trial 0 finished with value: 8.802447880412743e-06 and parameters: {'max_depth': 4, 'learning_rate': 0.10992905205027517, 'n_estimators': 76, 'subsample': 0.9330886997874446, 'colsample_bytree': 0.7950763579175599, 'reg_alpha': 0.003076691921828455, 'reg_lambda': 0.07500021586378287}. Best is trial 0 with value: 8.802447880412743e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:26,683] Trial 1 finished with value: 7.258600873251088e-06 and parameters: {'max_depth': 8, 'learning_rate': 0.08817108485574773, 'n_estimators': 92, 'subsample': 0.9302170700350694, 'colsample_bytree': 0.856885037911455, 'reg_alpha': 0.00024773304366344426, 'reg_lambda': 0.05663734934843198}. Best is trial 1 with value: 7.258600873251088e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:26,786] Trial 2 finished with value: 0.00029495398665230633 and parameters: {'max_depth': 8, 'learning_rate': 0.05294030095053519, 'n_estimators': 56, 'subsample': 0.8638475433534518, 'colsample_bytree': 0.8708271354818555, 'reg_alpha': 0.0001572543509981093, 'reg_lambda': 0.05577097392210848}. Best is trial 1 with value: 7.258600873251088e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:26,898] Trial 3 finished with value: 7.798851958409855e-06 and parameters: {'max_depth': 8, 'learning_rate': 0.212517383025274, 'n_estimators': 152, 'subsample': 0.7252885247926496, 'colsample_bytree': 0.6020166852342222, 'reg_alpha': 0.0001293081357915968, 'reg_lambda': 0.5076035545095734}. Best is trial 1 with value: 7.258600873251088e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:27,064] Trial 4 finished with value: 6.7450572179567645e-06 and parameters: {'max_depth': 5, 'learning_rate': 0.15899075309907, 'n_estimators': 155, 'subsample': 0.6894119835750784, 'colsample_bytree': 0.9265576915445818, 'reg_alpha': 0.00039558586742611244, 'reg_lambda': 0.10435524487602313}. Best is trial 4 with value: 6.7450572179567645e-06.
# [I 2025-06-30 05:28:27,227] Trial 5 finished with value: 6.575488297753929e-06 and parameters: {'max_depth': 6, 'learning_rate': 0.0611430572071325, 'n_estimators': 180, 'subsample': 0.8732044860379611, 'colsample_bytree': 0.7693146409195706, 'reg_alpha': 0.00042898628916893865, 'reg_lambda': 0.0018693543275243897}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:27,351] Trial 6 finished with value: 8.661468405733545e-06 and parameters: {'max_depth': 4, 'learning_rate': 0.04826949744482847, 'n_estimators': 149, 'subsample': 0.7674497563644815, 'colsample_bytree': 0.741912780737926, 'reg_alpha': 0.000306443262583729, 'reg_lambda': 0.032183101776195176}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:27,470] Trial 7 finished with value: 1.7050654769233703e-05 and parameters: {'max_depth': 3, 'learning_rate': 0.13603326272521982, 'n_estimators': 179, 'subsample': 0.632464886099801, 'colsample_bytree': 0.6353200598628578, 'reg_alpha': 0.011742604777445986, 'reg_lambda': 0.06889199909693708}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:27,605] Trial 8 finished with value: 0.0007467339048654374 and parameters: {'max_depth': 7, 'learning_rate': 0.016828599298989343, 'n_estimators': 125, 'subsample': 0.7549008801626403, 'colsample_bytree': 0.7406005822367911, 'reg_alpha': 0.013876931316948669, 'reg_lambda': 0.0398615699106689}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:27,732] Trial 9 finished with value: 1.2494086613551496e-05 and parameters: {'max_depth': 8, 'learning_rate': 0.12489337763745419, 'n_estimators': 112, 'subsample': 0.7534663601322847, 'colsample_bytree': 0.6719168164168127, 'reg_alpha': 0.03202518936809181, 'reg_lambda': 0.000138966411786694}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:27,945] Trial 10 finished with value: 8.719868522358553e-05 and parameters: {'max_depth': 6, 'learning_rate': 0.023179841185251043, 'n_estimators': 249, 'subsample': 0.8465983760769166, 'colsample_bytree': 0.9889378586802988, 'reg_alpha': 0.3482533443689031, 'reg_lambda': 0.001435786582480742}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:28,093] Trial 11 finished with value: 7.9448704345106e-06 and parameters: {'max_depth': 6, 'learning_rate': 0.2334755823893577, 'n_estimators': 209, 'subsample': 0.6438065530213043, 'colsample_bytree': 0.9884830974349409, 'reg_alpha': 0.0015968335744974316, 'reg_lambda': 0.002634164087729788}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:28,347] Trial 12 finished with value: 7.839776290325976e-06 and parameters: {'max_depth': 5, 'learning_rate': 0.03352593509265066, 'n_estimators': 287, 'subsample': 0.9932330216560592, 'colsample_bytree': 0.9030123013651921, 'reg_alpha': 0.0011061763477189677, 'reg_lambda': 0.6125372083417499}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:28,547] Trial 13 finished with value: 7.549872027179156e-06 and parameters: {'max_depth': 10, 'learning_rate': 0.07222660080226528, 'n_estimators': 204, 'subsample': 0.6940361057704952, 'colsample_bytree': 0.9315438940486179, 'reg_alpha': 0.0007802529611192021, 'reg_lambda': 0.006080248685886491}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:28,800] Trial 14 finished with value: 0.000530122354279853 and parameters: {'max_depth': 5, 'learning_rate': 0.01102760134248254, 'n_estimators': 225, 'subsample': 0.847349366779677, 'colsample_bytree': 0.8106967967459039, 'reg_alpha': 0.06519996075384296, 'reg_lambda': 0.0006125800415579573}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:28,949] Trial 15 finished with value: 8.648913245230787e-06 and parameters: {'max_depth': 5, 'learning_rate': 0.17417866621393038, 'n_estimators': 173, 'subsample': 0.678470252737462, 'colsample_bytree': 0.7214968173043207, 'reg_alpha': 0.0039002415169091227, 'reg_lambda': 0.01224106652693926}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:29,171] Trial 16 finished with value: 9.134020130405756e-06 and parameters: {'max_depth': 3, 'learning_rate': 0.0386958108303332, 'n_estimators': 266, 'subsample': 0.6035182971441047, 'colsample_bytree': 0.8010816820452515, 'reg_alpha': 0.0005874442758757889, 'reg_lambda': 0.259765042821588}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:29,320] Trial 17 finished with value: 0.00014569602976090298 and parameters: {'max_depth': 10, 'learning_rate': 0.07624018174149626, 'n_estimators': 183, 'subsample': 0.8162334823506576, 'colsample_bytree': 0.9477106941164188, 'reg_alpha': 0.7436183394252469, 'reg_lambda': 0.00046517712375488253}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:29,438] Trial 18 finished with value: 7.20694525761146e-06 and parameters: {'max_depth': 7, 'learning_rate': 0.2907866597159335, 'n_estimators': 141, 'subsample': 0.9008869282764626, 'colsample_bytree': 0.8613709863623027, 'reg_alpha': 0.003953213861490907, 'reg_lambda': 0.013761153717389714}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:29,620] Trial 19 finished with value: 1.2845397412329338e-05 and parameters: {'max_depth': 4, 'learning_rate': 0.16925318052930655, 'n_estimators': 222, 'subsample': 0.8051080321609724, 'colsample_bytree': 0.696339205129955, 'reg_alpha': 0.00040179403240400756, 'reg_lambda': 0.19483451594458834}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:29,801] Trial 20 finished with value: 0.0003297808500217277 and parameters: {'max_depth': 6, 'learning_rate': 0.02801480787409032, 'n_estimators': 106, 'subsample': 0.7108764991524182, 'colsample_bytree': 0.7703387147651668, 'reg_alpha': 0.0849484826021151, 'reg_lambda': 0.00254775837275735}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,000] Trial 21 finished with value: 9.967651967752226e-06 and parameters: {'max_depth': 7, 'learning_rate': 0.2909163995972353, 'n_estimators': 147, 'subsample': 0.9062848791176528, 'colsample_bytree': 0.8493900703200998, 'reg_alpha': 0.0041358889671671405, 'reg_lambda': 0.008678278734108707}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,130] Trial 22 finished with value: 7.0547783183288784e-06 and parameters: {'max_depth': 7, 'learning_rate': 0.2860814469063092, 'n_estimators': 135, 'subsample': 0.8805469123495718, 'colsample_bytree': 0.8851722895207615, 'reg_alpha': 0.000101695620051402, 'reg_lambda': 0.01818388128185224}. Best is trial 5 with value: 6.575488297753929e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,263] Trial 23 finished with value: 5.284703825435561e-06 and parameters: {'max_depth': 5, 'learning_rate': 0.1990063196289083, 'n_estimators': 186, 'subsample': 0.982686412826507, 'colsample_bytree': 0.902120760662853, 'reg_alpha': 0.00010035381469812592, 'reg_lambda': 0.018197502538027478}. Best is trial 23 with value: 5.284703825435561e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,391] Trial 24 finished with value: 7.981944084072476e-06 and parameters: {'max_depth': 5, 'learning_rate': 0.16449644825739726, 'n_estimators': 173, 'subsample': 0.9972740222140936, 'colsample_bytree': 0.9246990456001042, 'reg_alpha': 0.0002730187423324829, 'reg_lambda': 0.15938491500980895}. Best is trial 23 with value: 5.284703825435561e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,540] Trial 25 finished with value: 5.096188839442113e-06 and parameters: {'max_depth': 4, 'learning_rate': 0.09477044299797562, 'n_estimators': 194, 'subsample': 0.9496493331499487, 'colsample_bytree': 0.8286941927103819, 'reg_alpha': 0.0018315833934875285, 'reg_lambda': 0.0045766275367754945}. Best is trial 25 with value: 5.096188839442113e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,701] Trial 26 finished with value: 5.7169834685670075e-06 and parameters: {'max_depth': 4, 'learning_rate': 0.09876068800131581, 'n_estimators': 200, 'subsample': 0.9565924852621459, 'colsample_bytree': 0.8278785459185751, 'reg_alpha': 0.0006795942022199846, 'reg_lambda': 0.004431968458414994}. Best is trial 25 with value: 5.096188839442113e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:30,894] Trial 27 finished with value: 6.893975490265033e-06 and parameters: {'max_depth': 3, 'learning_rate': 0.10107706441733325, 'n_estimators': 200, 'subsample': 0.9629257270405926, 'colsample_bytree': 0.8119747527811345, 'reg_alpha': 0.0017714339771719122, 'reg_lambda': 0.005342083160720773}. Best is trial 25 with value: 5.096188839442113e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:31,121] Trial 28 finished with value: 5.700892936040758e-06 and parameters: {'max_depth': 4, 'learning_rate': 0.09567442907945031, 'n_estimators': 243, 'subsample': 0.9603268639467256, 'colsample_bytree': 0.8283509041233915, 'reg_alpha': 0.0010690369176763002, 'reg_lambda': 0.0008587406389122088}. Best is trial 25 with value: 5.096188839442113e-06.
# /tmp/ipython-input-5-1648268331.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-5-1648268331.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-5-1648268331.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-5-1648268331.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:28:31,276] Trial 29 finished with value: 8.08306824960817e-06 and parameters: {'max_depth': 4, 'learning_rate': 0.12160667450498146, 'n_estimators': 247, 'subsample': 0.9477178073905342, 'colsample_bytree': 0.8975649925146254, 'reg_alpha': 0.007419248031985781, 'reg_lambda': 0.0008530000822652003}. Best is trial 25 with value: 5.096188839442113e-06.
# Final MAE: 0.0006
# Final R² Score: -4291.0824
# Best Parameters: {'max_depth': 4, 'learning_rate': 0.09477044299797562, 'n_estimators': 194, 'subsample': 0.9496493331499487, 'colsample_bytree': 0.8286941927103819, 'reg_alpha': 0.0018315833934875285, 'reg_lambda': 0.0045766275367754945, 'objective': 'reg:squarederror', 'verbosity': 0}

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import optuna

# Load and preprocess data
df = pd.read_csv("/content/service-2-deployment_dataset.csv")
df["Timestamp"] = pd.to_datetime(df["Timestamp"], format = 'mixed')
df = df.sort_values("Timestamp")

# Feature engineering
df["cpu_allocated"] = df["CPU Request"]
df["memory_allocated"] = df["Memory Request"]
df["cpu_usage_pct"] = df["CPU Usage"] / df["CPU Limit"]
df["memory_usage_pct"] = df["Memory Usage"] / df["Memory Limit"]
df["request_rate_rps"] = df["Request Rate"]
df["latency_p95_t"] = df["Latency"].shift(1)
df["burstiness_score"] = df["Request Rate"].rolling(5).max() - df["Request Rate"].rolling(5).mean()

# Drop rows with NaNs from shifting
df = df.dropna()

# Define features and target
features = [
    "cpu_allocated", "memory_allocated",
    "cpu_usage_pct", "memory_usage_pct",
    "request_rate_rps", "latency_p95_t",
    "burstiness_score"
]
X = df[features]
y = df["Latency"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Optuna objective function
def objective(trial):
    params = {
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
        "n_estimators": trial.suggest_int("n_estimators", 50, 300),
        "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
        "objective": "reg:squarederror",
        "verbosity": 0,
    }

    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)

    model = xgb.train(
        params=params,
        dtrain=dtrain,
        num_boost_round=params["n_estimators"]
    )

    preds = model.predict(dtest)
    mae = mean_absolute_error(y_test, preds)
    return mae

# Run Optuna tuning
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# Best model
best_params = study.best_params
best_params["objective"] = "reg:squarederror"
best_params["verbosity"] = 0

# Train base model on initial batch
batch_size = 100
model = None
for i in range(0, len(X_train), batch_size):
    X_batch = X_train.iloc[i:i + batch_size]
    y_batch = y_train.iloc[i:i + batch_size]
    dtrain = xgb.DMatrix(X_batch, label=y_batch)

    model = xgb.train(
        params=best_params,
        dtrain=dtrain,
        num_boost_round=best_params["n_estimators"] // 5,
        xgb_model=model,  # warm-start
        #process_type="update",
        #updater="refresh"
    )

# Evaluate on test set
dtest = xgb.DMatrix(X_test)
y_pred = model.predict(dtest)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Final MAE:", round(mae, 4))
print("Final R² Score:", round(r2, 4))
print("Best Parameters:", best_params)
# Out:
# [I 2025-06-30 05:30:20,535] A new study created in memory with name: no-name-7afca264-2b45-4a15-b3ab-88ddb4c5bc5a
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:20,590] Trial 0 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 10, 'learning_rate': 0.01831916030903077, 'n_estimators': 110, 'subsample': 0.9225726177866339, 'colsample_bytree': 0.9208225437865629, 'reg_alpha': 0.020900589978509493, 'reg_lambda': 0.19313615137351411}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:20,680] Trial 1 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 7, 'learning_rate': 0.21234574864629738, 'n_estimators': 155, 'subsample': 0.7228029521853747, 'colsample_bytree': 0.9348138079179567, 'reg_alpha': 0.03264747607740085, 'reg_lambda': 0.0002126857291162022}. Best is trial 0 with value: 8.063535432437876e-07.
# [I 2025-06-30 05:30:20,803] Trial 2 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 8, 'learning_rate': 0.04682327381606129, 'n_estimators': 256, 'subsample': 0.729091396221509, 'colsample_bytree': 0.6404487768586787, 'reg_alpha': 0.2224809287126709, 'reg_lambda': 0.006810354008466404}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:20,852] Trial 3 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 6, 'learning_rate': 0.013562168571997792, 'n_estimators': 59, 'subsample': 0.6118627152111692, 'colsample_bytree': 0.8347720304494677, 'reg_alpha': 0.0025651269197705965, 'reg_lambda': 0.03510959711232211}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:20,927] Trial 4 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 3, 'learning_rate': 0.02342134330188932, 'n_estimators': 195, 'subsample': 0.688741734654116, 'colsample_bytree': 0.6281746791367602, 'reg_alpha': 0.0030594719600953017, 'reg_lambda': 0.015260379449262309}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,026] Trial 5 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 5, 'learning_rate': 0.023626172981548663, 'n_estimators': 201, 'subsample': 0.6566152396387575, 'colsample_bytree': 0.9985824622899266, 'reg_alpha': 0.42931423628060267, 'reg_lambda': 0.012422233132222927}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,067] Trial 6 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 9, 'learning_rate': 0.020621789983213304, 'n_estimators': 63, 'subsample': 0.7908557562737182, 'colsample_bytree': 0.8094948262526838, 'reg_alpha': 0.13002825461133832, 'reg_lambda': 0.0008937933940868897}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,159] Trial 7 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 6, 'learning_rate': 0.01608251097502648, 'n_estimators': 259, 'subsample': 0.9573280680279458, 'colsample_bytree': 0.9714563644142142, 'reg_alpha': 0.03971870338405834, 'reg_lambda': 0.0009803588945846774}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,281] Trial 8 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 9, 'learning_rate': 0.030295712235550887, 'n_estimators': 270, 'subsample': 0.9017929944945433, 'colsample_bytree': 0.8413746141339045, 'reg_alpha': 0.01816356925290965, 'reg_lambda': 0.9213469383569791}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,329] Trial 9 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 3, 'learning_rate': 0.02323236069517089, 'n_estimators': 100, 'subsample': 0.6140635117317302, 'colsample_bytree': 0.6082134857479645, 'reg_alpha': 0.0001138341656080436, 'reg_lambda': 0.0005571109277025003}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,436] Trial 10 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 10, 'learning_rate': 0.12426273764412762, 'n_estimators': 134, 'subsample': 0.8790086597686281, 'colsample_bytree': 0.7261227887240173, 'reg_alpha': 0.00027855998864937905, 'reg_lambda': 0.45055212905418396}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,534] Trial 11 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 8, 'learning_rate': 0.2828085806188056, 'n_estimators': 144, 'subsample': 0.7999629430357671, 'colsample_bytree': 0.9192949420027257, 'reg_alpha': 0.004892210637330706, 'reg_lambda': 0.00015017085559187443}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,637] Trial 12 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 10, 'learning_rate': 0.09262475280919508, 'n_estimators': 153, 'subsample': 0.9871536115856501, 'colsample_bytree': 0.8902447537472638, 'reg_alpha': 0.037490699462025656, 'reg_lambda': 0.08573538424649643}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,727] Trial 13 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 7, 'learning_rate': 0.2203037901308537, 'n_estimators': 116, 'subsample': 0.8689760536121091, 'colsample_bytree': 0.9219272149726102, 'reg_alpha': 0.06068566250137559, 'reg_lambda': 0.1941268442311901}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,850] Trial 14 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 5, 'learning_rate': 0.05725664618007666, 'n_estimators': 179, 'subsample': 0.752704896972192, 'colsample_bytree': 0.7536530985679104, 'reg_alpha': 0.0008342477270697836, 'reg_lambda': 0.0035044775171907618}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:21,936] Trial 15 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 8, 'learning_rate': 0.010226523307788218, 'n_estimators': 87, 'subsample': 0.9294998934129366, 'colsample_bytree': 0.8830111811379674, 'reg_alpha': 0.985197314748412, 'reg_lambda': 0.00010226661349319487}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,062] Trial 16 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 4, 'learning_rate': 0.15191066233861253, 'n_estimators': 220, 'subsample': 0.8356484777580242, 'colsample_bytree': 0.9444053656767316, 'reg_alpha': 0.012146908665219234, 'reg_lambda': 0.061955155955445776}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,176] Trial 17 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 7, 'learning_rate': 0.06391843299012936, 'n_estimators': 167, 'subsample': 0.7387239282662363, 'colsample_bytree': 0.758526873643687, 'reg_alpha': 0.008399847718149328, 'reg_lambda': 0.003304003527503326}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,357] Trial 18 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 9, 'learning_rate': 0.03729429425975664, 'n_estimators': 122, 'subsample': 0.843892886281359, 'colsample_bytree': 0.8707908834050321, 'reg_alpha': 0.07076250793827027, 'reg_lambda': 0.00033005984632577336}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,457] Trial 19 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 10, 'learning_rate': 0.08314008973712583, 'n_estimators': 85, 'subsample': 0.6792518745046051, 'colsample_bytree': 0.9515305036292114, 'reg_alpha': 0.0011765185471424113, 'reg_lambda': 0.002549621481441548}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,581] Trial 20 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 5, 'learning_rate': 0.16981631019807952, 'n_estimators': 228, 'subsample': 0.9998050669706612, 'colsample_bytree': 0.6883542262631558, 'reg_alpha': 0.020528458692789613, 'reg_lambda': 0.19816858313707272}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,708] Trial 21 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 8, 'learning_rate': 0.04495089661409503, 'n_estimators': 240, 'subsample': 0.742445252629396, 'colsample_bytree': 0.6613678884557304, 'reg_alpha': 0.1694181042771491, 'reg_lambda': 0.00610121747291342}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,858] Trial 22 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 7, 'learning_rate': 0.08165934033192135, 'n_estimators': 292, 'subsample': 0.7198592556757484, 'colsample_bytree': 0.793444406463701, 'reg_alpha': 0.23351331279196336, 'reg_lambda': 0.0320493215075944}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:22,975] Trial 23 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 8, 'learning_rate': 0.03536095797338395, 'n_estimators': 176, 'subsample': 0.7771559243002906, 'colsample_bytree': 0.9952670611979479, 'reg_alpha': 0.597011651932154, 'reg_lambda': 0.0018157416455487634}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:23,141] Trial 24 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 9, 'learning_rate': 0.1121629674349194, 'n_estimators': 298, 'subsample': 0.7042781064840764, 'colsample_bytree': 0.7014011644046623, 'reg_alpha': 0.0982049620899103, 'reg_lambda': 0.008904798019398162}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:23,257] Trial 25 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 6, 'learning_rate': 0.051001813919089735, 'n_estimators': 108, 'subsample': 0.8303528408431098, 'colsample_bytree': 0.9150511685866957, 'reg_alpha': 0.265562505884391, 'reg_lambda': 0.00026419392465125126}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:23,408] Trial 26 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 7, 'learning_rate': 0.29741978739052777, 'n_estimators': 157, 'subsample': 0.6490474936452432, 'colsample_bytree': 0.8528096822430646, 'reg_alpha': 0.029362797347171607, 'reg_lambda': 0.14897163679983247}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:23,531] Trial 27 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 8, 'learning_rate': 0.06862656524523375, 'n_estimators': 199, 'subsample': 0.7693314448141808, 'colsample_bytree': 0.787368466263279, 'reg_alpha': 0.007675573102580011, 'reg_lambda': 0.029257028987927345}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:23,641] Trial 28 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 10, 'learning_rate': 0.010204742170533711, 'n_estimators': 134, 'subsample': 0.723049084648061, 'colsample_bytree': 0.9611141856496649, 'reg_alpha': 0.05476812652003323, 'reg_lambda': 0.463765313428199}. Best is trial 0 with value: 8.063535432437876e-07.
# /tmp/ipython-input-6-2383550553.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
# /tmp/ipython-input-6-2383550553.py:44: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:45: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.6, 1.0),
# /tmp/ipython-input-6-2383550553.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-4, 1.0),
# /tmp/ipython-input-6-2383550553.py:47: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
# [I 2025-06-30 05:30:23,754] Trial 29 finished with value: 8.063535432437876e-07 and parameters: {'max_depth': 6, 'learning_rate': 0.030404577803700077, 'n_estimators': 62, 'subsample': 0.6255582687623454, 'colsample_bytree': 0.811418419181483, 'reg_alpha': 0.0016990591128366178, 'reg_lambda': 0.020360608644410798}. Best is trial 0 with value: 8.063535432437876e-07.
# Final MAE: 0.0
# Final R² Score: -0.0002
# Best Parameters: {'max_depth': 10, 'learning_rate': 0.01831916030903077, 'n_estimators': 110, 'subsample': 0.9225726177866339, 'colsample_bytree': 0.9208225437865629, 'reg_alpha': 0.020900589978509493, 'reg_lambda': 0.19313615137351411, 'objective': 'reg:squarederror', 'verbosity': 0}
